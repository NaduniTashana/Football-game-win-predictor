# %%
import pandas as pd

# %%
matches = pd.read_csv('matches.csv', index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2023-08-11  20:00  Premier League  Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League  Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League  Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League  Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League  Matchweek 5  Sat  Away      W   3   1
#
#         opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 1        Burnley  ...  Match Report    NaN  17.0   8.0  13.9  0.0  0     0
# 3  Newcastle Utd  ...  Match Report    NaN  14.0   4.0  17.9  0.0  0     0
# 4  Sheffield Utd  ...  Match Report    NaN  29.0   9.0  17.3  2.0  0     1
# 5         Fulham  ...  Match Report    NaN   6.0   4.0  14.8  0.0  1     1
# 6       West Ham  ...  Match Report    NaN  29.0  13.0  16.4  1.0  0     0
#
#    season             team
# 1    2022  Manchester City
# ...

# %%
matches.shape
# Out:
# (228, 27)

# %%
matches["team"].value_counts()
# Out:
# team
# Manchester City      38
# Arsenal              38
# Liverpool            38
# Aston Villa          38
# Tottenham Hotspur    38
# Chelsea              38
# Name: count, dtype: int64

# %%
matches[matches["team"]=="Liverpool"]
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 0   2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D   1   1
# 1   2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W   3   1
# 2   2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W   2   1
# 3   2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W   3   0
# 4   2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W   3   1
# 6   2023-09-24  14:00  Premier League   Matchweek 6  Sun  Home      W   3   1
# 8   2023-09-30  17:30  Premier League   Matchweek 7  Sat  Away      L   1   2
# 10  2023-10-08  14:00  Premier League   Matchweek 8  Sun  Away      D   2   2
# 11  2023-10-21  12:30  Premier League   Matchweek 9  Sat  Home      W   2   0
# 13  2023-10-29  14:00  Premier League  Matchweek 10  Sun  Home      W   3   0
# 15  2023-11-05  16:30  Premier League  Matchweek 11  Sun  Away      D   1   1
# ...

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     6
# Matchweek 30    6
# Matchweek 23    6
# Matchweek 24    6
# Matchweek 25    6
# Matchweek 18    6
# Matchweek 26    6
# Matchweek 27    6
# Matchweek 28    6
# Matchweek 31    6
# Matchweek 2     6
# Matchweek 32    6
# Matchweek 33    6
# Matchweek 29    6
# Matchweek 35    6
# Matchweek 36    6
# Matchweek 37    6
# Matchweek 34    6
# Matchweek 22    6
# Matchweek 21    6
# Matchweek 20    6
# Matchweek 19    6
# Matchweek 3     6
# Matchweek 4     6
# Matchweek 5     6
# Matchweek 6     6
# Matchweek 7     6
# Matchweek 8     6
# Matchweek 9     6
# Matchweek 10    6
# Matchweek 11    6
# Matchweek 12    6
# Matchweek 13    6
# Matchweek 14    6
# Matchweek 15    6
# Matchweek 16    6
# Matchweek 17    6
# Matchweek 38    6
# Name: count, dtype: int64

# %%
matches["date"]= pd.to_datetime(matches["date"])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                       int64
# ga                       int64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"]= matches["date"].dt.dayofweek

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 46 2024-05-02  19:30  Premier League  Matchweek 26  Thu  Home      W   2   0
# 47 2024-05-05  14:00  Premier League  Matchweek 36  Sun  Home      W   5   0
# 48 2024-05-11  17:30  Premier League  Matchweek 37  Sat  Away      W   3   2
# 49 2024-05-15  19:45  Premier League  Matchweek 34  Wed  Away      W   2   1
# 50 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      W   2   1
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf= RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
#split the trainig data and testing data
train= matches[matches["date"] < '2024-01-01']
test= matches[matches["date"] > '2024-01-01']

# %%
print(train.shape)
print(test.shape)
# Out:
# (118, 32)
# (109, 32)

# %%
predictors = ["venue_code","opp_code","hour","day_code"]

# %%
rf.fit(train[predictors],train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds= rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc= accuracy_score(test["target"],preds)

# %%
acc
# Out:
# 0.5963302752293578

# %%
combined= pd.DataFrame(dict(actual=test["target"],prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction   0   1
# actual
# 0           18  23
# 1           21  47

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"],preds)
# Out:
# 0.6714285714285714

# %%
grouped_matches= matches.groupby("team")

# %%
group= grouped_matches.get_group("Manchester City").sort_values("date")

# %%
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# 8  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W   2   0
# 10 2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L   1   2
# 12 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L   0   1
# 13 2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W   2   1
# 15 2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away      W   3   0
# 16 2023-11-04  15:00  Premier League  Matchweek 11  Sat  Home      W   6   1
# ...

# %%
#get previous 3 weeks performance and predict next week performances

def rolling_averages(group,cols,new_cols):
    group=group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean() #closed='left means not get the predict raw(last raw)
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# 8  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W   2   0
# 10 2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L   1   2
# 12 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L   0   1
# 13 2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W   2   1
# 15 2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away      W   3   0
# 16 2023-11-04  15:00  Premier League  Matchweek 11  Sat  Home      W   6   1
# 18 2023-11-12  16:30  Premier League  Matchweek 12  Sun  Away      D   4   4
# 19 2023-11-25  12:30  Premier League  Matchweek 13  Sat  Home      D   1   1
# 21 2023-12-03  16:30  Premier League  Matchweek 14  Sun  Home      D   3   3
# ...

# %%
#apply this for all teams
matches_rolling= matches.groupby("team").apply(lambda x: rolling_averages(group, cols, new_cols))
# Out:
# /var/folders/jt/5qd4bg814lj05bw6gq2c4qph0000gn/T/ipykernel_1178/1970244095.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling= matches.groupby("team").apply(lambda x: rolling_averages(group, cols, new_cols))

# %%
matches_rolling
# Out:
#                            date   time            comp         round  day  \
# team
# Arsenal           5  2023-09-02  15:00  Premier League   Matchweek 4  Sat
#                   6  2023-09-16  15:00  Premier League   Matchweek 5  Sat
#                   8  2023-09-23  15:00  Premier League   Matchweek 6  Sat
#                   10 2023-09-30  15:00  Premier League   Matchweek 7  Sat
#                   12 2023-10-08  16:30  Premier League   Matchweek 8  Sun
# ...                         ...    ...             ...           ...  ...
# Tottenham Hotspur 51 2024-04-28  16:30  Premier League  Matchweek 35  Sun
#                   52 2024-05-04  17:30  Premier League  Matchweek 36  Sat
#                   53 2024-05-11  12:30  Premier League  Matchweek 37  Sat
#                   54 2024-05-14  20:00  Premier League  Matchweek 34  Tue
#                   55 2024-05-19  16:00  Premier League  Matchweek 38  Sun
#
# ...

# %%
#drop extra index level that has team name
matches_rolling= matches_rolling.droplevel("team")

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# 8  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W   2   0
# 10 2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L   1   2
# 12 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L   0   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 51 2024-04-28  16:30  Premier League  Matchweek 35  Sun  Away      W   2   0
# 52 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Home      W   5   1
# 53 2024-05-11  12:30  Premier League  Matchweek 37  Sat  Away      W   4   0
# 54 2024-05-14  20:00  Premier League  Matchweek 34  Tue  Away      W   2   0
# 55 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      W   3   1
#
# ...

# %%
#indexing correction to 0 to 210
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 0   2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 1   2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# 2   2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W   2   0
# 3   2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L   1   2
# 4   2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L   0   1
# ..         ...    ...             ...           ...  ...   ...    ...  ..  ..
# 205 2024-04-28  16:30  Premier League  Matchweek 35  Sun  Away      W   2   0
# 206 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Home      W   5   1
# 207 2024-05-11  12:30  Premier League  Matchweek 37  Sat  Away      W   4   0
# 208 2024-05-14  20:00  Premier League  Matchweek 34  Tue  Away      W   2   0
# 209 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      W   3   1
#
# ...

# %%
#Retraing the model
def make_predictions(data, predictors):
    train = data[data["date"] < '2024-01-01']
    test = data[data["date"] > '2024-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision= make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.8333333333333334

# %%
#we can see that early precison is 67 and we have improved it to 83

# %%
combined
# Out:
#      actual  predicted
# 16        1          1
# 17        1          1
# 18        1          0
# 19        1          1
# 20        0          1
# ..      ...        ...
# 205       1          0
# 206       1          1
# 207       1          0
# 208       1          0
# 209       1          0
#
# [114 rows x 2 columns]

# %%
#this dont show the which teams are these,so we merge some columns
combined= combined.merge(matches_rolling[["date","team","opponent","result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#      actual  predicted       date             team         opponent result
# 16        1          1 2024-01-13  Manchester City    Newcastle Utd      W
# 17        1          1 2024-01-31  Manchester City          Burnley      W
# 18        1          0 2024-02-05  Manchester City        Brentford      W
# 19        1          1 2024-02-10  Manchester City          Everton      W
# 20        0          1 2024-02-17  Manchester City          Chelsea      D
# ..      ...        ...        ...              ...              ...    ...
# 205       1          0 2024-04-28  Manchester City  Nott'ham Forest      W
# 206       1          1 2024-05-04  Manchester City           Wolves      W
# 207       1          0 2024-05-11  Manchester City           Fulham      W
# 208       1          0 2024-05-14  Manchester City        Tottenham      W
# 209       1          0 2024-05-19  Manchester City         West Ham      W
#
# [114 rows x 6 columns]
